# %%
import numpy as np #linear algebra
import pandas as pd #data processing
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>

# %% [markdown]
# Reading And Displaying The Dataset

# %%
#Dataset Reading

DATASET_PATH = "./data/SQLiV3.csv"

df = pd.read_csv(DATASET_PATH, encoding="UTF-8")

df.head(10)#gives first 10 rows of the dataset
# Out:
#                                             Sentence Label Unnamed: 2  \
# 0                  " or pg_sleep  (  __TIME__  )  --     1        NaN
# 1  create user name identified by pass123 tempora...   NaN          1
# 2   AND 1  =  utl_inaddr.get_host_address   (    ...     1        NaN
# 3   select * from users where id  =  '1' or @ @1 ...     1        NaN
# 4   select * from users where id  =  1 or 1#"  ( ...     1        NaN
# 5   select name from syscolumns where id   =     ...     1        NaN
# 6  select * from users where id  =  1 +$+ or 1  =...     1        NaN
# 7  1;  (  load_file  (  char  (  47,101,116,99,47...     1        NaN
# 8   select * from users where id  =  '1' or ||/1 ...     1        NaN
# 9   select * from users where id  =  '1' or \.<\ ...     1        NaN
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %% [markdown]
# Data PreProcessing

# %%
#Removing Unwanted Columns

df = df.drop(columns=['Unnamed: 2','Unnamed: 3']) # Removing Unnamed Columns and Copying into df

df.shape
# Out:
# (30919, 2)

# %%
df.head()
# Out:
#                                             Sentence Label
# 0                  " or pg_sleep  (  __TIME__  )  --     1
# 1  create user name identified by pass123 tempora...   NaN
# 2   AND 1  =  utl_inaddr.get_host_address   (    ...     1
# 3   select * from users where id  =  '1' or @ @1 ...     1
# 4   select * from users where id  =  1 or 1#"  ( ...     1

# %%
print("----------------------------------------------------")
df.info()
print("----------------------------------------------------")
# Out:
# ----------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 30919 entries, 0 to 30918
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  30904 non-null  str
#  1   Label     30664 non-null  str
# dtypes: str(2)
# memory usage: 483.2 KB
# ----------------------------------------------------

# %%
df['Label'].describe()
#Count is non null values
#Unique is unique values
#Top is most frequent value
#Freq is frequency of the top value
# Out:
# count     30664
# unique       42
# top           0
# freq      19268
# Name: Label, dtype: object

# %%
df['Label'].isna().sum()
#Count NaN Label values

df.dropna(subset=['Label'], inplace=True)
#Dropping NaN Label values and Copying into df

# %%
df['Label'].isna().sum()
# Out:
# np.int64(0)

# %%
#Getting Unique Values
unique_values = df['Label'].unique()
print('\n'.join(l for l in unique_values))
#print(unique_values)
# Out:
# 1
#  if not  (  select system_user  )   <> 'sa' waitfor delay '0:0:2' --
#  execute immediate 'sel' || 'ect us' || 'er'
#  exec xp_regread
# SELECT *
#  --
#  desc users
#  OR
#  exec master..xp_cmdshell 'ping 172.10.1.255'--
#  exec master..xp_cmdshell
#  if is_srvrolemember  (  'sysadmin'  )   > 0 waitfor delay '0:0:2' --
# waitfor delay '0:0:__TIME__'--
#  exec   (  'sel' + 'ect us' + 'er'  )
#  drop table temp --
#  if not   (    (   select serverproperty  (  'isintegratedsecurityonly'   )    )    <> 0  )   waitfor delay '0:0:2' --
#  exec master..xp_cmdshell 'ping 10.10.1.2'--
#  if not   (    (   select serverproperty  (  'isintegratedsecurityonly'   )    )    <> 1  )   waitfor delay '0:0:2' --
#  begin declare @var varchar  (  8000  )   set @var  =  ':' select @var  =  @var+'+login+'/'+password+' ' from users where login >
#  or '1'  =  '1'
#  begin declare @var varchar  (  8000  )   set @var  =  ' ...
# 0
#  grant resource to name
# s
#  EXEC SelectAllCustomers
#  /*Select all the columns of all the records in the Customers table:*/
# */
#  CREATE VIEW [Products Above Average Price] AS
#  CREATE OR REPLACE VIEW view_name AS
#  DROP TABLE Suppliers
#  CREATE PROCEDURE SelectAllCustomers AS
#   EXEC SelectAllCustomers
#  DELETE FROM Customers  WHERE CustomerName = 'Alfreds Futterkiste'
#  CREATE OR REPLACE VIEW [Brazil Customers] AS
#   SELECT * FROM CustomersLIMIT 3
# SELECT * FROM Customers
#  SELECT TOP 50 PERCENT * FROM Customers
#  SELECT * FROM CustomersFETCH FIRST 50 PERCENT ROWS ONLY
# SELECT TOP 3 * FROM Customers
#  SELECT * FROM Customers
# SELECT SUM ( Quantity )
#  SELECT column_name ( s )
#  SELECT City FROM Customers

# %%
#Dropping Unique Labels Which is not 0 or 1
df = df.drop(df[(df['Label'] != '0') & (df['Label'] != '1')].index)

# %%
df['Label'].unique()
# Out:
# <StringArray>
# ['1', '0']
# Length: 2, dtype: str

# %%
df['Label'].describe()
# Out:
# count     30609
# unique        2
# top           0
# freq      19268
# Name: Label, dtype: object

# %%
df.head(100)
# Out:
#                                               Sentence Label
# 0                    " or pg_sleep  (  __TIME__  )  --     1
# 2     AND 1  =  utl_inaddr.get_host_address   (    ...     1
# 3     select * from users where id  =  '1' or @ @1 ...     1
# 4     select * from users where id  =  1 or 1#"  ( ...     1
# 5     select name from syscolumns where id   =     ...     1
# ..                                                 ...   ...
# 97    AND 1  =  utl_inaddr.get_host_address   (    ...     1
# 98                              or 1  =  1 or ''  =  '     1
# 99   select * from users where id  =  1   or 1  =  ...     1
# 100                                    or 'text' > 't'     1
# 101  1234 " AND 1  =  0 UNION ALL SELECT "admin", "...     1
#
# [100 rows x 2 columns]

# %% [markdown]
# Converting Data Type

# %%
#Converting Data Type
df['Label'] = df['Label'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 30609 entries, 0 to 30918
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sentence  30609 non-null  str
#  1   Label     30609 non-null  int64
# dtypes: int64(1), str(1)
# memory usage: 717.4 KB

# %%
#Count of how many 1 and 0 in the Label column
df['Label'].value_counts()
# Out:
# Label
# 0    19268
# 1    11341
# Name: count, dtype: int64

# %% [markdown]
# Distrubition Of Label

# %%
f, ax=plt.subplots(1,2, figsize=(12,8))
#making 2 subplots 1 row 2 columns
#f is figure and ax is axis

df['Label'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True,wedgeprops={'alpha':0.5})
#making exploding pie chart


ax[0].set_title('Label')
ax[0].set_ylabel('')

sns.countplot(x='Label', data=df, ax=ax[1], alpha=0.9, hue='Label', palette='pastel')
#making countplot of data at x axis with seaborn
ax[1].set_title('Label')
plt.show()

# %% [markdown]
# Content of the Data

# %%
df.head()
# Out:
#                                             Sentence  Label
# 0                  " or pg_sleep  (  __TIME__  )  --      1
# 2   AND 1  =  utl_inaddr.get_host_address   (    ...      1
# 3   select * from users where id  =  '1' or @ @1 ...      1
# 4   select * from users where id  =  1 or 1#"  ( ...      1
# 5   select name from syscolumns where id   =     ...      1

# %%
#How many comment symbols are in payloads?
comment_values= df[df.Sentence.str.contains('#|--|//')]
print(comment_values)
# Out:
#                                                 Sentence  Label
# 0                      " or pg_sleep  (  __TIME__  )  --      1
# 3       select * from users where id  =  '1' or @ @1 ...      1
# 4       select * from users where id  =  1 or 1#"  ( ...      1
# 5       select name from syscolumns where id   =     ...      1
# 6      select * from users where id  =  1 +$+ or 1  =...      1
# ...                                                  ...    ...
# 19330                                  â or 1  =  1 --      1
# 19334                                      or 3  =  3 --      1
# 19337  0" encoding  =  "utf-8" ?>   <_filter>  <![CDA...      0
# 19338  org/?option  =  com_k2  <a href  =  "http://co...      0
# 19339  com/?option  =  com_k2  <act>  <![CDATA[procMe...      0
#
# [5905 rows x 2 columns]

# %%
comment_values.count()['Sentence']
# Out:
# np.int64(5905)

# %% [markdown]
# SQL Tables in payloads

# %%
from_values=df[df.Sentence.str.contains('from', case=False)]
print(from_values)
# Out:
#                                                 Sentence  Label
# 2       AND 1  =  utl_inaddr.get_host_address   (    ...      1
# 3       select * from users where id  =  '1' or @ @1 ...      1
# 4       select * from users where id  =  1 or 1#"  ( ...      1
# 5       select name from syscolumns where id   =     ...      1
# 6      select * from users where id  =  1 +$+ or 1  =...      1
# ...                                                  ...    ...
# 30914              DELETE FROM door WHERE grow = 'small'      0
# 30915                               DELETE FROM tomorrow      0
# 30916                       SELECT wide ( s )  FROM west      0
# 30917       SELECT * FROM  ( SELECT slide FROM breath )       0
# 30918                           SELECT TOP 3 * FROM race      0
#
# [14245 rows x 2 columns]

# %%
#Print existing tables in the payload

l= list(from_values.Sentence)
Sql_tables=[]

for i in l:
    starting_point=i.lower().index('from') + 5

    x=i[starting_point: ].split(' ')

    if x[0] not in Sql_tables and len(x[0]) > 1:
        Sql_tables.append(x[0])

        
print(Sql_tables)
# Out:
# ['users', 'syscolumns', 'sysobjects', 'information_schema.tables--', 'DUAL', 'temp', 'where', 'global_name', 'sys.all_tab_columns', 'v$instance', 'sys.all_tables', 'v$version', 'SYS.ALL_USERS', 'DBA_ROLE_PRIVS', 'SYS.USER$', 'wapiti', 'generate_series', 'information_schema.character_sets', 'dual', 'pg_sleep', 'all_users', 'sysibm.systables', 'rdb$database', 'sysusers', 'mysql.db', 'domain.domains', 'rdb$fields', 'master..sysdatabases', 'information_schema.system_users', 'dual--', 'dual#', 'Home]]>', 'wp_options', 'wp_houzez_fields_builder', 'wp_sm_sync', '`wp_options`', 'wp_posts', 'wp_favethemes_currency_converter', 'wp_houzez_currencies', 'wp_postmeta', 'wp_users', 'wp_usermeta', 'wp_houzez_crm_viewed_listings', 'wp_terms', 'wp_termmeta', 'wp_term_relationships', 'table_name', 'Customers;', 'Customers', 'Products', 'Customers,', 'Orders', 'table1', 'Suppliers', 'Suppliers;', 'oldtable', 'OrderDetails;', 'Products;', 'existing_table_name', 'Users', 'customers;', 'Employees;', '"2017-06-15"', '"2017-06-15', 'Books', 'CustomersWHERE', 'ProductsWHERE', 'OrdersINNER', 'table1INNER', 'table1LEFT', 'table1RIGHT', 'OrdersRIGHT', 'CustomersFULL', 'SuppliersWHERE', 'CustomersGROUP', 'by', 'positive', 'blow', 'damage', 'organization', 'baby', 'dish', 'outer', 'fox', 'left', 'son', 'door', 'spend', 'curve', 'sheep', 'origin', 'outside', 'manner', 'equal', 'stepped', 'strange', 'check', 'interest', 'correctly', 'yellow', 'size', 'after', 'sense', 'neck', 'particular', 'greatly', 'farm', 'breakfast', 'fair', 'direction', 'mirror', 'firm', 'fur', 'exist', 'wild', 'escape', 'of', 'none', 'comfortable', 'bee', 'recognize', 'apart', 'discuss', 'zebra', 'obtain', 'longer', 'pencil', 'gray', 'glass', 'directly', 'sudden', 'instance', 'business', 'upper', 'heavy', 'other', 'sky', 'angry', 'frame', 'local', 'tree', 'consider', 'short', 'bank', 'topic', 'especially', 'guard', 'member', 'felt', 'two', 'itself', 'describe,came', 'solar', 'wait', 'ran', 'mix', 'wore', 'land', 'sang', 'length', 'mainly', 'relationship', 'coffee', 'gradually', 'there', 'country', 'anyway', 'yet', 'industrial', 'twelve', 'interior', 'football', 'women', 'did', 'frozen', 'surrounded', 'against', 'managed', 'smell', 'port', 'happily', 'chosen', 'behavior', 'half', 'mixture', 'pet', 'explore', 'anybody', 'flies', 'everything', 'search', 'yourself', 'grabbed', 'future', 'engineer', 'tune', 'wealth', 'since', 'trap', 'make', 'threw', 'lion', 'rush', 'toward', 'thee', 'certain', 'division', 'simply', 'pure', 'recent', 'electric', 'paper', 'important', 'verb', 'layers', 'teach', 'calm', 'very', 'down', 'fruit', 'cost', 'swing', 'character', 'way', 'melted', 'became', 'rubbed', 'harder', 'terrible', 'further', 'classroom', 'only', 'slept', 'running', 'love', 'plain,amount', 'also', 'object', 'success', 'daughter', 'frog', 'riding', 'least', 'experiment', 'piano', 'kitchen', 'rise', 'substance', 'good', 'mood', 'tall', 'identity', 'storm', 'easier', 'sit', 'hunter', 'mighty', 'who', 'question', 'eat', 'serious', 'cast', 'coming', 'nine', 'favorite', 'present', 'weather', 'rain', 'negative', 'act', 'planned', 'through', 'loose', 'line', 'situation', 'disease', 'round', 'congress', 'real', 'open', 'hay', 'close', 'with', 'crop', 'came', 'bottle', 'ahead', 'raw', 'center', 'broken', 'composition', 'mean', 'column', 'pressure', 'building', 'dirty', 'bar', 'invented', 'whatever', 'think', 'flame', 'value', 'tobacco', 'compare', 'have', 'ranch', 'function', 'officer', 'hospital', 'transportation', 'larger', 'receive', 'black', 'ago,alike', 'rice', 'trip', 'weak', 'sink', 'effort', 'oil', 'struggle', 'earlier', 'bottom', 'carbon', 'lying', 'tape', 'off', 'buy', 'low', 'clear', 'taken', 'graph', 'spin', 'camp', 'husband', 'held', 'refused', 'putting', 'hour', 'solid', 'deal', 'sail', 'yard', 'home', 'allow', 'inch', 'influence', 'kept', 'might', 'arrow', 'bowl', 'factor', 'found', 'caught', 'anyone', 'voyage', 'history', 'child', 'flag', 'car', 'language', 'organized', 'pilot', 'it', 'm ...
